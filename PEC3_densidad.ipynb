# %% [markdown]
# <a href="https://colab.research.google.com/github/dlopezuj/TFM_getrificacion_BCN/blob/main/PEC3_densidad.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Procesado de datos refrentes a las densidad de población

# %% [markdown]
# ## 1.1 Lectura de Datos de densidad de población de 2019 a 2015

# %% [markdown]
# link a la fuente de datos:
# https://opendata-ajuntament.barcelona.cat/data/en/dataset/est-densitat

# %%
# import de liberias
import pandas as pd

# %%
# Lectura de datos de Incidentes
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# se realiza la lectura de los diversos archivos csv y se guardan en cinco datasets (uno para cada año)
df_densidad_2019=pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/Evolucion_demografica/datasets/densidad poblacion/2019_densitat.csv')
df_densidad_2018=pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/Evolucion_demografica/datasets/densidad poblacion/2018_densitat.csv')
df_densidad_2017=pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/Evolucion_demografica/datasets/densidad poblacion/2017_densitat.csv')
df_densidad_2016=pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/Evolucion_demografica/datasets/densidad poblacion/2016_densitat.csv')
df_densidad_2015=pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/Evolucion_demografica/datasets/densidad poblacion/2015_densitat.csv')

# %% [markdown]
# ## 1.2 Exploracion de los datos

# %%
df_densidad_2019.head()
# Out:
#     Any  Codi_Districte Nom_Districte  Codi_Barri  \
# 0  2019               1  Ciutat Vella           1
# 1  2019               1  Ciutat Vella           2
# 2  2019               1  Ciutat Vella           3
# 3  2019               1  Ciutat Vella           4
# 4  2019               2      Eixample           5
#
#                                Nom_Barri  Població  Superfície (ha)  \
# 0                               el Raval     47353            110.0
# 1                         el Barri Gòtic     18629             81.6
# 2                         la Barceloneta     14857            109.5
# 3  Sant Pere, Santa Caterina i la Ribera     22590            111.0
# 4                          el Fort Pienc     32349             92.9
#
#    Superfície Residencial (ha)  Densitat (hab/ha)  Densitat neta (hab/ha)
# 0                         49.6                430                     955
# 1                         34.1                228                     546
# ...

# %%
df_densidad_2018.head()
# Out:
#     Any  Codi_Districte Nom_Districte  Codi_Barri  \
# 0  2018               1  Ciutat Vella           1
# 1  2018               1  Ciutat Vella           2
# 2  2018               1  Ciutat Vella           3
# 3  2018               1  Ciutat Vella           4
# 4  2018               2      Eixample           5
#
#                                Nom_Barri  Població  Superfície (ha)  \
# 0                               el Raval     46948            110.0
# 1                         el Barri Gòtic     16731             81.6
# 2                         la Barceloneta     14739            108.5
# 3  Sant Pere, Santa Caterina i la Ribera     22296            111.0
# 4                          el Fort Pienc     31922             92.9
#
#    Superfície Residencial (ha)  Densitat (hab/ha)  Densitat neta (hab/ha)
# 0                         49.6                427                     946
# 1                         34.0                205                     492
# ...

# %%
df_densidad_2017.head()
# Out:
#     Any  Codi_Districte Nom_Districte  Codi_Barri  \
# 0  2017               1  Ciutat Vella           1
# 1  2017               1  Ciutat Vella           2
# 2  2017               1  Ciutat Vella           3
# 3  2017               1  Ciutat Vella           4
# 4  2017               2      Eixample           5
#
#                                Nom_Barri  Població  Superfície (ha)  \
# 0                               el Raval     47608            109.8
# 1                         el Barri Gòtic     16062             84.2
# 2                         la Barceloneta     14996            131.4
# 3  Sant Pere, Santa Caterina i la Ribera     22721            111.4
# 4                          el Fort Pienc     32016             92.9
#
#    Superfície Residencial (ha)  Densitat (hab/ha)  Densitat neta (hab/ha)
# 0                         49.7                433                     959
# 1                         34.1                191                     471
# ...

# %%
df_densidad_2016.head()
# Out:
#     Any  Codi_Districte Nom_Districte  Codi_Barri  \
# 0  2016               1  Ciutat Vella           1
# 1  2016               1  Ciutat Vella           2
# 2  2016               1  Ciutat Vella           3
# 3  2016               1  Ciutat Vella           4
# 4  2016               2      Eixample           5
#
#                                Nom_Barri  Població  Superfície (ha)  \
# 0                               el Raval     47129            109.8
# 1                         el Barri Gòtic     15614             84.2
# 2                         la Barceloneta     15021            131.4
# 3  Sant Pere, Santa Caterina i la Ribera     22306            111.4
# 4                          el Fort Pienc     31653             92.9
#
#    Densitat (hab/ha)  Densitat neta (hab/ha)
# 0                429                     948
# 1                185                     457
# 2                114                    1113
# 3                200                     689
# ...

# %%
df_densidad_2015.head()
# Out:
#     Any  Codi_Districte Nom_Districte  Codi_Barri  \
# 0  2015               1  Ciutat Vella           1
# 1  2015               1  Ciutat Vella           2
# 2  2015               1  Ciutat Vella           3
# 3  2015               1  Ciutat Vella           4
# 4  2015               2      Eixample           5
#
#                                Nom_Barri  Població  Superfície (ha)  \
# 0                               el Raval     47142            109.8
# 1                         el Barri Gòtic     15484             84.2
# 2                         la Barceloneta     15032            131.4
# 3  Sant Pere, Santa Caterina i la Ribera     22457            111.4
# 4                          el Fort Pienc     31543             92.9
#
#    Densitat (hab/ha)  Densitat neta (hab/ha)
# 0                429                     949
# 1                184                     454
# 2                114                    1149
# 3                202                     695
# ...

# %% [markdown]
# Vemos como los nombres de las columnas y el número de columnas son ligeramente distintos en varios conjuntos de datos, por lo que procedemos a eliminar las columnas que no nos hacen falta y a estandarizar el nombre de las columnas que nos interesan. Decidimos quedarnos con el valor referente a la Densitat neta (hab/ha)

# %%
# se eliminan las columnas no relevantes
df_densidad_drop_2019 = df_densidad_2019.drop(['Codi_Districte', 'Nom_Districte', 'Nom_Barri', 'Població', 'Superfície (ha)','Superfície Residencial (ha)', 'Densitat (hab/ha)'], axis=1)
df_densidad_drop_2018 = df_densidad_2018.drop(['Codi_Districte', 'Nom_Districte', 'Nom_Barri', 'Població', 'Superfície (ha)','Superfície Residencial (ha)', 'Densitat (hab/ha)'], axis=1)
df_densidad_drop_2017 = df_densidad_2017.drop(['Codi_Districte', 'Nom_Districte', 'Nom_Barri', 'Població', 'Superfície (ha)','Superfície Residencial (ha)', 'Densitat (hab/ha)'], axis=1)
df_densidad_drop_2016 = df_densidad_2016.drop(['Codi_Districte', 'Nom_Districte', 'Nom_Barri', 'Població', 'Superfície (ha)', 'Densitat (hab/ha)'], axis=1)
df_densidad_drop_2015 = df_densidad_2015.drop(['Codi_Districte', 'Nom_Districte', 'Nom_Barri', 'Població', 'Superfície (ha)', 'Densitat (hab/ha)'], axis=1)

# %%
# revisamos que los datos tienen el formato deseado
df_densidad_drop_2015
# Out:
#      Any  Codi_Barri  Densitat neta (hab/ha)
# 0   2015           1                     949
# 1   2015           2                     454
# 2   2015           3                    1149
# 3   2015           4                     695
# 4   2015           5                     944
# ..   ...         ...                     ...
# 68  2015          69                     581
# 69  2015          70                     891
# 70  2015          71                    1496
# 71  2015          72                    1147
# 72  2015          73                     717
#
# [73 rows x 3 columns]

# %% [markdown]
# # 2. Concatenación de los dataframes

# %%
# relizamos la concatenación de los datasets en un unico dataset
union_densidad = pd.concat([df_densidad_drop_2019, df_densidad_drop_2018, df_densidad_drop_2017, \
                             df_densidad_drop_2016, df_densidad_drop_2015], ignore_index=True)

# %%
# Se revisa si hay valores null en el conjunto de datos final
union_densidad.isnull().any()
# Out:
# Any                       False
# Codi_Barri                False
# Densitat neta (hab/ha)    False
# dtype: bool

# %%
# renombro la columna 
union_densidad.columns = union_densidad.columns.str.replace('Densitat neta (hab/ha)', 'Densidad neta (hab/ha)')
# Out:
# <ipython-input-13-4ed76f38fcc4>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   union_densidad.columns = union_densidad.columns.str.replace('Densitat neta (hab/ha)', 'Densidad neta (hab/ha)')

# %%
union_densidad
# Out:
#       Any  Codi_Barri  Densitat neta (hab/ha)
# 0    2019           1                     955
# 1    2019           2                     546
# 2    2019           3                    1097
# 3    2019           4                     697
# 4    2019           5                     962
# ..    ...         ...                     ...
# 360  2015          69                     581
# 361  2015          70                     891
# 362  2015          71                    1496
# 363  2015          72                    1147
# 364  2015          73                     717
#
# [365 rows x 3 columns]

# %% [markdown]
# # 3. Escritura de los datos en un nuevo csv

# %%
union_densidad.to_csv('/content/gdrive/MyDrive/Colab Notebooks/Evolucion_demografica/output_evolucion_demografica/union_densidad.csv', index = False)
